# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import quandl
quandl.ApiConfig.api_key='XpNcJG2guvU6TT-EVKGQ'
stock = quandl.get('WIKI/T')
stock2 = quandl.get('WIKI/KO')

# %%
stock.head()
# Out:
#              Open   High    Low  Close    Volume  Ex-Dividend  Split Ratio  \
# Date
# 1984-07-19  59.75  59.87  59.38  59.38   77900.0          0.0          1.0
# 1984-07-20  59.62  60.00  59.25  59.50  129800.0          0.0          1.0
# 1984-07-23  59.25  59.75  58.75  59.50  276100.0          0.0          1.0
# 1984-07-24  59.75  60.38  59.62  60.00  129100.0          0.0          1.0
# 1984-07-25  60.00  61.37  59.87  60.75  152400.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1984-07-19   1.275248   1.277809  1.267351    1.267351     934800.0
# 1984-07-20   1.272474   1.280584  1.264577    1.269913    1557600.0
# 1984-07-23   1.264577   1.275248  1.253905    1.269913    3313200.0
# 1984-07-24   1.275248   1.288694  1.272474    1.280584    1549200.0
# 1984-07-25   1.280584   1.309824  1.277809    1.296591    1828800.0

# %%
stock.drop(['Ex-Dividend','Split Ratio','Adj. Open','Adj. High','Adj. Low','Adj. Close','Adj. Volume'], axis=1).head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 1984-07-19  59.75  59.87  59.38  59.38   77900.0
# 1984-07-20  59.62  60.00  59.25  59.50  129800.0
# 1984-07-23  59.25  59.75  58.75  59.50  276100.0
# 1984-07-24  59.75  60.38  59.62  60.00  129100.0
# 1984-07-25  60.00  61.37  59.87  60.75  152400.0

# %%
stock['2015':'2018'].describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  813.000000  813.000000  813.000000  813.000000  8.130000e+02
# mean    37.198954   37.446962   36.949582   37.204797  2.575362e+07
# std      3.053925    3.051431    3.050866    3.063708  1.142825e+07
# min     31.990000   32.180000   30.970000   31.800000  6.862360e+06
# 25%     34.370000   34.620000   34.170000   34.400000  1.873282e+07
# 50%     37.130000   37.470000   36.900000   37.140000  2.295044e+07
# 75%     39.220000   39.415000   39.000000   39.210000  2.985332e+07
# max     43.500000   43.890000   43.330000   43.470000  1.005742e+08
#
#        Ex-Dividend  Split Ratio   Adj. Open   Adj. High    Adj. Low  \
# count   813.000000        813.0  813.000000  813.000000  813.000000
# mean      0.007085          1.0   34.982856   35.216503   34.747627
# std       0.057928          0.0    3.854051    3.866726    3.833943
# min       0.000000          1.0   28.333025   28.567541   27.655736
# ...

# %%
stock.index
# Out:
# DatetimeIndex(['1984-07-19', '1984-07-20', '1984-07-23', '1984-07-24',
#                '1984-07-25', '1984-07-26', '1984-07-27', '1984-07-30',
#                '1984-07-31', '1984-08-01',
#                ...
#                '2018-03-14', '2018-03-15', '2018-03-16', '2018-03-19',
#                '2018-03-20', '2018-03-21', '2018-03-22', '2018-03-23',
#                '2018-03-26', '2018-03-27'],
#               dtype='datetime64[ns]', name='Date', length=8492, freq=None)

# %%
plt.figure(figsize=(15, 6))
stock.Close.plot();
plt.title('AT&T', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(15, 6))
stock['2000-01-01':'2018-01-01']['Close'].plot()
plt.title('AT&T', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.grid()

# %%
plt.figure(figsize=(15, 6))
stock['Open']['2018'].plot()
stock2['Open']['2018'].plot()
plt.title('AT&T', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.grid()
